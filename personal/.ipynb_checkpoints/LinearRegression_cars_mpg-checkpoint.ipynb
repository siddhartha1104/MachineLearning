# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("../datasets/auto-mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
df['origin'] = df['origin'].replace({1:'america', 2:'europe', 3:'asia'})

# %%
df.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
#
#     origin                   car name
# 0  america  chevrolet chevelle malibu
# 1  america          buick skylark 320

# %%
df = df.drop('car name',axis = 1)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#     origin
# 0  america
# 1  america
# 2  america
# 3  america
# 4  america

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %%
hpisDigit = pd.DataFrame(df.horsepower.str.isdigit())

# %%
df[hpisDigit['horsepower'] == False]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model year   origin
# 32           71  america
# 126          74  america
# 330          80   europe
# 336          80  america
# 354          81   europe
# 374          82  america

# %%
df = df.replace('?', np.nan)
df[hpisDigit['horsepower'] == False]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0        NaN    2046          19.0
# 126  21.0          6         200.0        NaN    2875          17.0
# 330  40.9          4          85.0        NaN    1835          17.3
# 336  23.6          4         140.0        NaN    2905          14.3
# 354  34.5          4         100.0        NaN    2320          15.8
# 374  23.0          4         151.0        NaN    3035          20.5
#
#      model year   origin
# 32           71  america
# 126          74  america
# 330          80   europe
# 336          80  america
# 354          81   europe
# 374          82  america

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
medianCheack = df.drop('origin', axis = 1)
medianCheack
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# 393          82
# 394          82
# 395          82
# 396          82
# 397          82
#
# [398 rows x 7 columns]

# %%
medianCheack.median()
# Out:
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# horsepower        93.5
# weight          2803.5
# acceleration      15.5
# model year        76.0
# dtype: object

# %% [markdown]
# # to replace NaN value with -> median

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
df[hpisDigit['horsepower'] == False]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0       93.5    2046          19.0
# 126  21.0          6         200.0       93.5    2875          17.0
# 330  40.9          4          85.0       93.5    1835          17.3
# 336  23.6          4         140.0       93.5    2905          14.3
# 354  34.5          4         100.0       93.5    2320          15.8
# 374  23.0          4         151.0       93.5    3035          20.5
#
#      model year   origin
# 32           71  america
# 126          74  america
# 330          80   europe
# 336          80  america
# 354          81   europe
# 374          82  america

# %% [markdown]
# # above values are replaced with median value

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %% [markdown]
# # we have to conver Horsepower -> object to --> float

# %%
df['horsepower'] = df['horsepower'].astype('float64')

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %% [markdown]
# # to create dummies variables

# %%
df = pd.get_dummies(df,['origin'])

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin_america  origin_asia  origin_europe
# 0            70            True        False          False
# 1            70            True        False          False
# 2            70            True        False          False
# 3            70            True        False          False
# 4            70            True        False          False
# ..          ...             ...          ...            ...
# 393          82            True        False          False
# 394          82           False        False           True
# 395          82            True        False          False
# 396          82            True        False          False
# 397          82            True        False          False
#
# [398 rows x 10 columns]

# %%
df.dtypes
# Out:
# mpg               float64
# cylinders           int64
# displacement      float64
# horsepower        float64
# weight              int64
# acceleration      float64
# model year          int64
# origin_america       bool
# origin_asia          bool
# origin_europe        bool
# dtype: object

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin_america  origin_asia  origin_europe
# 0            70            True        False          False
# 1            70            True        False          False
# 2            70            True        False          False
# 3            70            True        False          False
# 4            70            True        False          False
# ..          ...             ...          ...            ...
# 393          82            True        False          False
# 394          82           False        False           True
# 395          82            True        False          False
# 396          82            True        False          False
# 397          82            True        False          False
#
# [398 rows x 10 columns]

# %%
x = df.drop('mpg', axis = 1)
y = df['mpg']

# %%
x.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0          8         307.0       130.0    3504          12.0          70
# 1          8         350.0       165.0    3693          11.5          70
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
#
#    origin_america  origin_asia  origin_europe
# 0            True        False          False
# 1            True        False          False
# 2            True        False          False
# 3            True        False          False
# 4            True        False          False

# %%
y.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=0)

# %%
y_test
# Out:
# 65     14.0
# 132    25.0
# 74     13.0
# 78     21.0
# 37     18.0
#        ...
# 286    17.6
# 263    17.7
# 146    28.0
# 259    20.8
# 63     14.0
# Name: mpg, Length: 100, dtype: float64

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)*100
# Out:
# 82.20975257022599

# %%
model.score(x_test, y_test)*100
# Out:
# 82.09521517724224

# %%
model.coef_
# Out:
# array([-0.3238232 ,  0.02488104, -0.02168627, -0.00671939,  0.20518937,
#         0.75768197, -1.96630356,  1.30485497,  0.66144859])

# %%
model.intercept_
# Out:
# -17.391065915907518

# %%
model.predict(x)
# Out:
# array([14.82656052, 13.76486545, 14.91825598, 14.795269  , 14.54707526,
#        10.35286884, 10.20525534, 10.14497204,  9.84981739, 12.54743716,
#        15.04324559, 13.47075275, 14.46691386, 18.84708667, 23.5470326 ,
#        18.74806974, 19.12602251, 20.77026026, 24.82423867, 28.30501328,
#        21.49962834, 22.37045177, 23.17251212, 23.12662467, 20.02187543,
#         7.24705397,  8.06477765,  7.77350594,  6.46799678, 25.58192064,
#        22.64206472, 25.06711801, 23.70414997, 21.06746174, 15.88872395,
#        17.35831467, 17.79997357, 17.18595115, 11.15793452, 10.36908345,
#        12.12040157, 11.6515163 ,  6.53845172,  8.68524023,  5.92936743,
#        19.39613932, 22.78298759, 17.57153152, 18.69004551, 22.26882041,
#        25.31232253, 26.2832414 , 25.41158081, 28.75597389, 29.5640236 ,
#        28.4580228 , 24.95885903, 25.79661431, 23.79422577, 27.44702887,
#        23.25291137, 23.49915945, 11.47885585, 11.76019227, 12.24973658,
#        12.94347372, 14.60210296,  9.89449624, 10.47148066, 10.67214146,
#        11.2888753 , 24.24739306, 13.32902553, 12.76098285, 11.51309237,
#        12.74205614, 20.37719685, 24.71164989, 21.61132729, 26.40507286,
#        22.26098709, 25.70416662, 24.19019771, 23.14095055, 26.95156319,
#        13.39403913, 15.35978493, 14.79719944, 13.72133651, 15.20777242,
#         8.82814875, 12.52919884, 12.02038601, 12.52722968, 10.0886875 ,
#         8.79365115, 15.10718185, 19.74604473, 19.72934116, 21.1086621 ,
#        21.40867675, 20.64663332, 29.90792351,  9.3581403 ,  9.29315454,
#        10.0287363 , 10.50197467, 21.95169828, 27.01944697, 24.44798198,
#        25.97810789, 26.5410742 , 24.1244773 , 21.80891311, 25.73345781,
#        14.16557636, 11.53113114, 29.37124027, 27.22558578, 23.67203603,
#        21.77682884, 17.43991949, 22.91005138, 22.42606677, 15.80488505,
#        20.17646986, 21.88665859, 22.16199743, 19.89210888, 29.99536274,
#        23.63277724, 31.01607669, 23.68019708, 16.90197831, 18.09054307,
#        17.19778459, 13.64614493, 10.97674461, 11.60145548, 10.71698459,
#        13.00737859, 27.1572252 , 28.54644142, 26.28612581, 31.755578  ,
#        29.8688766 , 24.72515924, 27.67233047, 27.08417697, 25.92238605,
#        26.47165402, 28.40041851, 20.41480327, 19.50968459, 21.43270205,
#        22.96603209, 12.1374862 , 13.48058643, 12.28883164, 11.87970535,
#        16.94417162, 17.07956322, 18.39491375, 17.52956684, 21.54546984,
#        20.13842176, 20.76324862, 28.92685892, 23.61260761, 22.83232728,
